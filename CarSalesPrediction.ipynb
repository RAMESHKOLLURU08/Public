# %% [markdown]
# **Importing Libraries**

# %% [markdown]
# # Car Sales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing the Dataset**

# %%
df_cars = pd.read_csv("/content/Car_sales.csv")

# %%
df_cars
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df_cars.shape
# Out:
# (157, 16)

# %%
df_cars.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
df_cars.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778

# %%
df_cars.tail(2)
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 155         101.623357
# 156          85.735655

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %% [markdown]
# **Observations:** On observing the above data, we can see that there are missing values in the columns - _year_resale_value, Price_in_thousands, Engine_size, Horse_power, Wheelbase, Width, Length, Curb_weight, Fuel_capacity, Fuel_efficiency, Power_perf_factor.Also convert the Latest_Launch column data type into datetime.

# %%
df_cars.duplicated().value_counts()
# Out:
# False    157
# dtype: int64

# %%
df_cars.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
df_cars['Year']= pd.to_datetime(df_cars.Latest_Launch,format='%m/%d/%Y').dt.year

# %%
df_cars.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor  Year
# 0          58.280150  2012
# 1          91.370778  2011

# %% [markdown]
# ### **Exploratory Data Analysis**

# %% [markdown]
# **Here, we are going to answer the following questions:**
#
# 1)How is the variable 'Sales_in_thousands' distributed?
#
# 2)Top 10 manufacturers with most models manufactured?
#
# 3)What are the different types of vehicles used in this dataset?
#
# 4)How is the variable 'Price_in_thousands' distributed?
#
# 5)Understanding the variables 'Engine_size' and 'Horsepower' for each manufacturer.
#
# 6)Understanding the variables 'Fuel_capacity' and 'Fuel_efficiency' for each manufacturer.
#
# 7)How many vehicles are launched every year?
#
# 8)How is the variable 'Power_performance_factor' distributed?
#
# 9)Manufacturer with the highest average sales.
#
# 10)Correlation between all the variables.

# %% [markdown]
# **1)How is the variable 'Sales_in_thousands' distributed?**

# %%
df_cars["Sales_in_thousands"].value_counts()
# Out:
# 16.919     1
# 1.112      1
# 42.643     1
# 88.094     1
# 79.853     1
#           ..
# 155.787    1
# 125.338    1
# 220.650    1
# 540.561    1
# 18.969     1
# Name: Sales_in_thousands, Length: 157, dtype: int64

# %%
plt.hist(list(df_cars['Sales_in_thousands']), bins = 20)
plt.xlabel("Sales in thousands")
plt.ylabel("Frequency")
plt.title("Understanding the distribution of the variable - Sales_in_thousands")
plt.show()

# %% [markdown]
# **Observations:**  On observing the above data, we can say that the distribution of the variable 'Sales_in_thousands' is right skewed with most of the values between 0 and 25 thousand, and outlier at the far end in the right.

# %% [markdown]
# **2)Top 10 manufacturers with most models manufactured?**

# %%
df_cars.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor  Year
# 0          58.280150  2012
# 1          91.370778  2011

# %%
 Top10_manufacture= df_cars.groupby(by=['Manufacturer'])["Model"].size().nlargest(10)

# %%
 Top10_manufacture
# Out:
# Manufacturer
# Dodge         11
# Ford          11
# Chevrolet      9
# Mercedes-B     9
# Toyota         9
# Chrysler       7
# Mitsubishi     7
# Nissan         7
# Lexus          6
# Mercury        6
# Name: Model, dtype: int64

# %%
figure=plt.figure(figsize=(15,7))
Top10_manufacture.plot.bar(color='pink')
plt.xlabel("Top 10 Manufacturers",color='green')
plt.xticks(rotation=45)
plt.ylabel("Models manufactured",color='green')
plt.title("Top 10 manufacturers with most models manufactured",color='green')
plt.show()

# %% [markdown]
# **3)What are the different types of vehicles used in this dataset?**

# %%
df_cars.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor  Year
# 0          58.280150  2012
# 1          91.370778  2011

# %%
df_cars['Vehicle_type'].value_counts()
# Out:
# Passenger    116
# Car           41
# Name: Vehicle_type, dtype: int64

# %%
figure=plt.figure(figsize=(15,7))
ax=df_cars['Vehicle_type'].value_counts().plot.bar(color='orange')
ax.bar_label(ax.containers[0], label_type='edge')
plt.title("Frequency of Vehicles",size=16,color='brown')
plt.xlabel("Types of Vehicles",size=16,color='brown')
plt.xticks(rotation=45)
plt.ylabel("Frequency",size=16,color='brown')
plt.show()

# %% [markdown]
# **Observations:** On observing the above graph, we can say that the count of passenger vehicle type is almost three times than car vehicle type.

# %% [markdown]
# **4. How is the variable 'Price_in_thousands' distributed?**

# %%
df_cars['Price_in_thousands'].value_counts()
# Out:
# 18.890    2
# 38.900    2
# 12.640    2
# 18.270    1
# 26.249    1
#          ..
# 26.935    1
# 12.885    1
# 15.350    1
# 20.550    1
# 36.000    1
# Name: Price_in_thousands, Length: 152, dtype: int64

# %%
figure=plt.figure(figsize=(15,7))
plt.hist(list(df_cars['Price_in_thousands']), bins = 20,color='green')
plt.xlabel(xlabel='Price in Thousands',size=14,color='red')
plt.ylabel(ylabel='Frequency ',size=14,color='red')
plt.title("Histogram showing the distribution of the variable - 'Price_in_thousands'",size=15,color='red')
plt.show()

# %% [markdown]
# **Observations:** On observing the above graph, we can say that the graph is right skewed with the majority of the values lying between 10 and 25, and has outliers at the far right end of the graph.

# %% [markdown]
# **5. Understanding the variables 'Engine_size' and 'Horsepower' for the top 5 manufacturers with most models manufactured.**

# %%
df_cars.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor  Year
# 0          58.280150  2012
# 1          91.370778  2011

# %%
df_cars['Manufacturer'].value_counts().nlargest(10)
# Out:
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Volvo          6
# Oldsmobile     6
# Name: Manufacturer, dtype: int64

# %%
df_cars.groupby(by=['Manufacturer'])['Engine_size'].value_counts().nlargest(5)
# Out:
# Manufacturer  Engine_size
# Volkswagen    2.0            5
# Nissan        3.3            4
# Buick         3.8            3
# Cadillac      4.6            3
# Dodge         2.5            3
# Name: Engine_size, dtype: int64

# %%
df_cars.groupby(by=['Manufacturer'])['Horsepower'].value_counts().nlargest(5)
# Out:
# Manufacturer  Horsepower
# Volkswagen    115.0         5
# Nissan        170.0         4
# Cadillac      275.0         3
# Acura         225.0         2
# BMW           193.0         2
# Name: Horsepower, dtype: int64

# %%
top_5_manufacturers = [manufacturer for manufacturer in Top10_manufacture[: 5]]

# %%
top_5_manufacturers
# Out:
# [11, 11, 9, 9, 9]

# %%
figure=plt.figure(figsize=(15,7))
sns.scatterplot(x=df_cars.Engine_size,y=df_cars.Horsepower,hue='Manufacturer')
plt.show()

# %%
figure=plt.figure(figsize=(15,7))
ax=pd.DataFrame({'Engine_size':df_cars.groupby(by=['Manufacturer',"Model"])['Engine_size'].value_counts(),'Horsepower':df_cars.groupby(by=['Manufacturer',"Model"])['Horsepower'].value_counts()})
ax.plot(kind="bar",figsize=(15, 8))

# %% [markdown]
# **7. How many vehicles are launched every year?**

# %%
df_cars.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor  Year
# 0          58.280150  2012
# 1          91.370778  2011

# %%
df_cars['Year'].value_counts()
# Out:
# 2011    79
# 2012    75
# 2009     2
# 2008     1
# Name: Year, dtype: int64

# %%
#figure=plt.figure(figsize=(15,7))
ax=df_cars['Year'].value_counts().plot.bar(color='red')
ax.bar_label(ax.containers[0], label_type='edge')
plt.title("No.of Launches per Year",size=16,color='green')
plt.xlabel("Year",size=16,color='green')
plt.ylabel("No.of Launches in the Year",size=16,color='green')
plt.show()

# %% [markdown]
# **Observations:** On observing the above graph, we can say that the years 2011 and 2012 have the maximum launches. We will use the same data to encode these values during the Data preprocessing.

# %% [markdown]
# **8. How is the variable 'Power_performance_factor' distributed?**

# %%
df_cars['Power_perf_factor'].value_counts()
# Out:
# 52.084899    2
# 58.280150    1
# 86.272523    1
# 63.313728    1
# 89.427820    1
#             ..
# 47.389531    1
# 89.401935    1
# 42.879097    1
# 54.269548    1
# 85.735655    1
# Name: Power_perf_factor, Length: 154, dtype: int64

# %%
plt.hist(df_cars['Power_perf_factor'], bins = 20,color='green')
plt.xlabel("Distribution of Power performance factor",color='orange')
plt.ylabel("Frequency",color='orange')
plt.title("Distribution of the variable - Power_perf_factor",color='orange')
plt.show()

# %% [markdown]
# **Observations**: On observing the above graph, we can say that the graph is normally distributed with slightly right skewed.

# %% [markdown]
# **9. Top 5 manufacturers with the highest average sales.**

# %%
df_cars.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor  Year
# 0          58.280150  2012
# 1          91.370778  2011

# %%
 df_cars.groupby(by=['Manufacturer'])["Sales_in_thousands"].mean().nlargest(10)
# Out:
# Manufacturer
# Ford         183.875909
# Honda        118.534800
# Jeep          97.717667
# Dodge         82.740818
# Toyota        82.245000
# Pontiac       61.755667
# Chevrolet     61.596111
# Buick         60.504750
# Nissan        57.090714
# Hyundai       45.775333
# Name: Sales_in_thousands, dtype: float64

# %%
df_cars.groupby(by=['Manufacturer'])["Sales_in_thousands"].mean().nlargest(5).plot.bar(color='brown')
plt.xlabel("Manufacturers",color='green')
plt.ylabel("Average sales of each manufacturer",color='green')
plt.title("Top 5 manufacturers with highest average sales",color='green')
plt.show()

# %% [markdown]
# **Observations:** On observing the above graph, we can see that the average sales for the manufacturer Ford is very high than compared to any other manufacturer.

# %% [markdown]
# **10. Correlation between all the variables**

# %%
figure=plt.figure(figsize=(15,7))
sns.heatmap(df_cars.corr(), annot=True)
plt.show()
# Out:
# <ipython-input-43-0d3aff879a1e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_cars.corr(), annot=True)

# %% [markdown]
# **Observations:** On observing the above correlation matrix, we can say that the pair of the variables (_year_resale_value, Price_in_thousands), (horsepower, Price_in_thousands), (horsepower, engine_size), (length, wheel_base), (curb_weight, engine_size), (fuel_capacity, curb_weight), (power_perf_factor, _year_resale_value), (power_perf_factor, price_in_thousands), (power_perf_factor, engine_size), (power_perf_factor, horsepower) have a strong positive association that means if the value of one variable increases, then the value of the other variable also increases. Similarly, the pair of variables (fuel_efficiency, engine_size), (fuel_efficiency, curb_weight), (fuel_efficiency, fuel_capacity) have a strong negative association that means as the value of one variable increases the value of other variable decreases.
